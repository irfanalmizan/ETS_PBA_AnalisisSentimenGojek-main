# %%
# ================================================================
# 📦 PREPROCESSING PIPELINE - GOJEK SENTIMENT ANALYSIS
# ================================================================

# Install required packages
# !pip uninstall nltk -y -q
# !pip install pandas numpy nltk Sastrawi wordcloud seaborn matplotlib -q

import pandas as pd
import numpy as np
import re
import logging
from nltk.tokenize import word_tokenize
import nltk
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# ================================================================
# 🧩 Fix NLTK Resources
# ================================================================
import shutil
import os
for path in nltk.data.path:
    if os.path.exists(path):
        shutil.rmtree(path, ignore_errors=True)

# ✅ Gunakan local path biar tidak kena SSL error
nltk.data.path.append("/Users/irfan/nltk_data")

# Pastikan resource ada (tanpa koneksi)
try:
    nltk.download('punkt', quiet=True)
    nltk.download('punkt_tab', quiet=True)
except:
    pass

# ================================================================
# 🧾 Load Data
# ================================================================
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

try:
    df = pd.read_csv('gojek_news_augmented_full_pipeline.csv')
    logger.info("✅ Berhasil memuat file gojek_news_augmented_full_pipeline.csv")
except FileNotFoundError:
    logger.error("❌ File gojek_news_augmented_full_pipeline.csv tidak ditemukan.")
    raise

required_columns = ['judul', 'cleaned_content', 'label', 'is_augmented']
if not all(col in df.columns for col in required_columns):
    missing_cols = [col for col in required_columns if col not in df.columns]
    raise ValueError(f"DataFrame tidak memiliki kolom yang diperlukan: {missing_cols}")

# ================================================================
# 🔤 1. Normalisasi Teks
# ================================================================
def normalize_text(text):
    try:
        if not isinstance(text, str):
            return ''
        text = text.lower()
        text = re.sub(r'[^\w\s]', ' ', text)
        text = re.sub(r'\d+', '', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text
    except Exception as e:
        logger.error(f"Error in normalize_text: {e}")
        return text

df['normalized_content'] = df['cleaned_content'].apply(normalize_text)
logger.info("✅ Normalisasi teks selesai.")

# ================================================================
# ✂️ 2. Tokenisasi
# ================================================================
df['tokens'] = df['normalized_content'].apply(word_tokenize)
df['word_count'] = df['tokens'].apply(len)
logger.info("✅ Tokenisasi dan perhitungan jumlah kata selesai.")

# ================================================================
# 🧹 3. Stopwords Removal
# ================================================================
stopword_factory = StopWordRemoverFactory()
stopwords_id = stopword_factory.get_stop_words()

custom_stopwords = [
    'yang','dan','di','dengan','untuk','pada','ini','dari','ke','dalam',
    'tersebut','adalah','oleh','sebagai','akan','telah','juga','serta','atau',
    'baca','klik','berita','the','of','to','lebih','hingga','antara','setelah',
    'sebelum','selama','terhadap','melalui','karena','bahwa','agar','supaya'
]
stopwords_id.extend(custom_stopwords)
stopwords_id = list(set(stopwords_id))
logger.info(f"✅ Total {len(stopwords_id)} stopwords digunakan (kecuali 'gojek').")

def remove_stopwords(text, stopwords_list):
    try:
        if not text:
            return ''
        words = text.split()
        filtered_words = [word for word in words if word not in stopwords_list or word == 'gojek']
        return ' '.join(filtered_words)
    except Exception as e:
        logger.error(f"Error in remove_stopwords: {e}")
        return text

df['content_without_stopwords'] = df['normalized_content'].apply(lambda x: remove_stopwords(x, stopwords_id))
df['word_count_no_stopwords'] = df['content_without_stopwords'].apply(lambda x: len(x.split()))
logger.info("✅ Penghapusan stopwords selesai.")

# ================================================================
# 🪶 4. Stemming
# ================================================================
stemmer_factory = StemmerFactory()
stemmer = stemmer_factory.create_stemmer()
stem_cache = {}

def stem_text(text):
    try:
        if not text:
            return ''
        if text in stem_cache:
            return stem_cache[text]
        words = text.split()
        stemmed_words = [word if word == 'gojek' else stemmer.stem(word) for word in words]
        stemmed_text = ' '.join(stemmed_words)
        stem_cache[text] = stemmed_text
        return stemmed_text
    except Exception as e:
        logger.error(f"Error in stem_text: {e}")
        return text

df['content_stemmed'] = df['content_without_stopwords'].apply(stem_text)
df['word_count_stemmed'] = df['content_stemmed'].apply(lambda x: len(x.split()))
logger.info("✅ Stemming selesai (kecuali 'gojek').")

# ================================================================
# 🔍 5. Rare & Common Words Removal
# ================================================================
def get_word_frequencies(text_series):
    all_words = ' '.join(text_series).split()
    return Counter(all_words)

word_frequencies = get_word_frequencies(df['content_stemmed'])
freq_values = list(word_frequencies.values())
rare_threshold = 2
common_threshold = int(np.percentile(freq_values, 99))
logger.info(f"✅ Rare threshold: {rare_threshold}, Common threshold: {common_threshold}")

def remove_rare_common_words(text, word_freq, rare_thresh, common_thresh):
    if not text:
        return ''
    words = text.split()
    filtered_words = [
        word for word in words
        if (rare_thresh <= word_freq.get(word, 0) <= common_thresh) or word == 'gojek'
    ]
    return ' '.join(filtered_words)

df['filtered_content'] = df['content_stemmed'].apply(
    lambda x: remove_rare_common_words(x, word_frequencies, rare_threshold, common_threshold)
)
df['word_count_filtered'] = df['filtered_content'].apply(lambda x: len(x.split()))
logger.info("✅ Penghapusan rare/common words selesai (kecuali 'gojek').")

# ================================================================
# ✅ 6. Validasi & Pengganti Teks Kosong
# ================================================================
empty_texts = df[df['filtered_content'].str.strip() == '']
if not empty_texts.empty:
    logger.warning(f"Terdapat {len(empty_texts)} teks kosong setelah preprocessing.")
    df.loc[df['filtered_content'].str.strip() == '', 'filtered_content'] = df['normalized_content']

# ================================================================
# 📊 7. Analisis Frekuensi & Visualisasi
# ================================================================
freq_df = get_word_frequencies(df['filtered_content'])
freq_df = pd.DataFrame(freq_df.items(), columns=['word', 'count']).sort_values(by='count', ascending=False)

# Barplot Top 50
plt.figure(figsize=(15, 10))
sns.barplot(x='count', y='word', data=freq_df.head(50), palette='viridis')
plt.title('Top 50 Most Frequent Words After Preprocessing (Gojek)', fontsize=16)
plt.xlabel('Frequency', fontsize=14)
plt.ylabel('Words', fontsize=14)
plt.tight_layout()
plt.savefig('gojek_top_50_words.png')
plt.show()

# Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(
    ' '.join(df['filtered_content'])
)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud After Preprocessing (Gojek)', fontsize=16)
plt.savefig('gojek_wordcloud_filtered.png')
plt.show()

# Distribusi Label
plt.figure(figsize=(8, 6))
sns.countplot(x='label', data=df, palette='viridis')
plt.title('Distribusi Label Setelah Preprocessing (Gojek)', fontsize=16)
plt.xlabel('Label', fontsize=14)
plt.ylabel('Jumlah Data', fontsize=14)
plt.tight_layout()
plt.savefig('gojek_label_distribution.png')
plt.show()

# ================================================================
# 💾 8. Simpan Hasil
# ================================================================
output_file_csv = 'gojek_news_preprocessed_final.csv'
output_file_excel = 'gojek_news_preprocessed_final.xlsx'
df.to_csv(output_file_csv, index=False)
df.to_excel(output_file_excel, index=False)
logger.info(f"✅ DataFrame disimpan ke {output_file_csv} dan {output_file_excel}")

# ================================================================
# 🧭 9. Ringkasan
# ================================================================
logger.info(f"Total data: {len(df)}")
logger.info(f"Distribusi label:\n{df['label'].value_counts().to_string()}")
logger.info(f"Top 10 kata:\n{freq_df.head(10).to_string()}")
logger.info(df[['judul', 'filtered_content', 'label', 'is_augmented']].head().to_string())
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# 2025-10-28 16:32:37,964 - INFO - ✅ Berhasil memuat file gojek_news_augmented_full_pipeline.csv
# 2025-10-28 16:32:37,999 - INFO - ✅ Normalisasi teks selesai.
# 2025-10-28 16:32:38,188 - INFO - ✅ Tokenisasi dan perhitungan jumlah kata selesai.
# 2025-10-28 16:32:38,189 - INFO - ✅ Total 815 stopwords digunakan (kecuali 'gojek').
# 2025-10-28 16:32:38,508 - INFO - ✅ Penghapusan stopwords selesai.
# 2025-10-28 16:32:38,963 - INFO - ✅ Stemming selesai (kecuali 'gojek').
# 2025-10-28 16:32:38,972 - INFO - ✅ Rare threshold: 2, Common threshold: 178
# 2025-10-28 16:32:38,984 - INFO - ✅ Penghapusan rare/common words selesai (kecuali 'gojek').
# /var/folders/77/vv2j_079111byz0tpny0xplc0000gp/T/ipykernel_12230/3449497380.py:187: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='count', y='word', data=freq_df.head(50), palette='viridis')
# /var/folders/77/vv2j_079111byz0tpny0xplc0000gp/T/ipykernel_12230/3449497380.py:208: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='label', data=df, palette='viridis')
# 2025-10-28 16:32:40,156 - INFO - ✅ DataFrame disimpan ke gojek_news_preprocessed_final.csv dan gojek_news_preprocessed_final.xlsx
# 2025-10-28 16:32:40,157 - INFO - Total data: 300
# 2025-10-28 16:32:40,157 - INFO - Distribusi label:
# label
# negatif    100
# positif    100
# netral     100
# 2025-10-28 16:32:40,158 - INFO - Top 10 kata:
#          word  count
# 206     gojek   1557
# 338  platform    178
# 262    terima    178
# 52     tinggi    175
# 271     waktu    172
# 26     dampak    171
# 5        zona    171
# 2       bijak    169
# 551    daring    164
# 411     bayar    161
# 2025-10-28 16:32:40,159 - INFO -                                                          judul                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            filtered_content    label  is_augmented
# 0                   pakar transportasi ingatkan dampak negatif                                                                                                                                                                                                                                                     yogyakarta tengah bijak laku berbedabeda zona wilayah operasional butuh lokal timbang penting rencana tuai perhati kalang akademisi teliti pusat studi logistik pustral ugm dwi ardianta kurniawan dampak positif cenderung sensitif jarak pendek alam minta rute pendek risiko kamis gerus dwi sederhana juta aktif alih kerja anggap janji cenderung dirugikanmeski fakta sebab ubah ekspektasi kondisi pasar anggap tinggi realitas ubah sama harap bisnis tugas negara sisi bisnis tengah juang catat rugi cetak untung situasi peran krusial bijak adil pihak lanjut industri fungsi awas netral profit tuju utama lupa sejahtera dwi usul solusi patok mekanisme solusi dwi usul patok wajar acu turut besar upah minimum regional umr jadi referensi layak adil tekan transparansi bagi kerap sumber konflik kunci jelas akuntabilitas bagi adil  negatif         False
